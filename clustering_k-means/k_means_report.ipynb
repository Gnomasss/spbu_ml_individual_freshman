# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnomasss/spbu_ml_individual_freshman/blob/main/clustering_k-means/k_means_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Создание тестов**
# Было создано 4 плоских набора данных

# %% [markdown]
# # **1 Тест**
# ![blobs.png](data:image/png;base64,...)

# %% [markdown]
# # **2 Тест**
# ![nested.png](data:image/png;base64,...)

# %% [markdown]
# # **3 Тест**
# ![nearby.png](data:image/png;base64,...)

# %% [markdown]
# # **4 Тест**
# ![nested_nearby.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Реализация k-means**
# >  **1. k-means**
#
# ```
# kmeans = KMeans(n_clusters=k).fit(X)
# ```
# > **2. Поиск оптимального числа кластеров** \\
# Для поиска оптимального числа кластеров воспользуемся подобием иерархической кластеризации. Мы переберм всевозможные значения в каком-то заранее известном диапазоне. Для каждого посчитаем значения силуэта, по которому можно определить насколько удачно прошла кластеризация. Он тоже встроен в scikit-learn. Вот его формула.
# ![image.png](data:image/png;base64,...)
#
# Для числа классов, при котором это значение максимально построим кластеризацию.

# %% [markdown]
# # **3. Результат**
# **1) Тест** \\
# **Силуэт:** 0.773; **Кол-во кластеров:** 5; **Время:** 1.578; \\
# **2) Тест** \\
# **Силуэт:** 0.408; **Кол-во кластеров:** 3; **Время:** 1.968; \\
# **3) Тест** \\
# **Силуэт:** 0.498; **Кол-во кластеров:** 7; **Время:** 1.641; \\
# **4) Тест** \\
# **Силуэт:** 0.494; **Кол-во кластеров:** 2; **Время:** 2.875; \\
# ![res1.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Вывод**
# 1) k-means плохо справляется с кластеризацией вложенных структур \\
# 2) Недостаток метрики силуэтов можно заметить в 3 тесте. Она больше на неправильной кластеризации. Если задать кол-во классов равное 2, то кластеризация пройдет корректно. \\
# 3) Не смотря на 3 тест, в 4 похожие данные разделились почти правильно. Из чего можно сделаь вывод, что метрика зависит от того, что внутри кольца тоже есть точки.
