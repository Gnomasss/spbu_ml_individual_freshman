# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnomasss/spbu_ml_individual_freshman/blob/main/regression/report_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Генерация данных**
#
#
# ```
# def f(x):
#     yw = x ** 4 + x ** 2 + 1
#     mu = np.mean(yw)
#     sd = np.std(yw)
#     jitter = 0.1 * np.random.normal(mu, sd, size=len(x))
#     y = yw + jitter
#     return y
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Линейная регрессия**
#
#
# ```
# lin_reg = LinearRegression()
# lin_reg = lin_reg.fit(X, y)
# y_lin_fit = lin_reg.predict(X)
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **3. Полиномиальная регрессия i-ой степени**
#
#
# ```
# pol = PolynomialFeatures(degree=i)
# x_i = pol.fit_transform(X)
# lin_reg = lin_reg.fit(x_i, y)
# y_i = lin_reg.predict(pol.fit_transform(X))
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Экспонента**
#
#
# ```
# transformer = FunctionTransformer(np.log, validate=True)
# y_trans = transformer.fit_transform(y)
# regressor = LinearRegression()
# results = regressor.fit(X, y_trans)
# y_fit = results.predict(X)
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **5. Вывод**
# Опираясь коэффициент детеминации, мы можем сделать вывод, что нашу функцию хорошо описывает как полином 5 степени, так и 4. \\
# Итоговым ответом станет 4, потому что 5 степени проще подстроится под результаты, но при рассмотрении функции на более больших промежутках точность будет уменьшаться. К примеру наши точки идеально бы описывал полином 200 степени, но при дальнейшем рассмотрении функции начались бы огормные различия.

# %% [markdown]
# # **Экспонента**
# f(x) = 1.5*e^(0.13*x) + 2*x
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Линейнная регрессия**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Полиномаильная i-ой степени**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Экспонента**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Вывод**
# Как мы видим, экспоненциальная регрессия лучше всего описывает экспоненту, что и следовало ожидать.
